# %%
from pyspark.ml.regression import LinearRegression
from pyspark.ml.regression import DecisionTreeRegressor
from pyspark.ml.feature import StringIndexer,VectorIndexer
from pyspark.ml.pipeline import Pipeline
from pyspark.ml.evaluation import RegressionEvaluator

# %%
data=spark.read.format('libsvm').load("/FileStore/tables/sample_linear_regression_data.txt")
data.collect()
# Out:
# Out[2]: [Row(label=-9.490009878824548, features=SparseVector(10, {0: 0.4551, 1: 0.3664, 2: -0.3826, 3: -0.4458, 4: 0.3311, 5: 0.8067, 6: -0.2624, 7: -0.4485, 8: -0.0727, 9: 0.5658})),
#  Row(label=0.2577820163584905, features=SparseVector(10, {0: 0.8387, 1: -0.127, 2: 0.4998, 3: -0.2269, 4: -0.6452, 5: 0.1887, 6: -0.5805, 7: 0.6519, 8: -0.6556, 9: 0.1749})),
#  Row(label=-4.438869807456516, features=SparseVector(10, {0: 0.5026, 1: 0.1421, 2: 0.16, 3: 0.505, 4: -0.9372, 5: -0.2842, 6: 0.6356, 7: -0.1646, 8: 0.9481, 9: 0.4268})),
#  Row(label=-19.782762789614537, features=SparseVector(10, {0: -0.0389, 1: -0.4167, 2: 0.8997, 3: 0.641, 4: 0.2733, 5: -0.2618, 6: -0.2795, 7: -0.1307, 8: -0.0854, 9: -0.0546})),
#  Row(label=-7.966593841555266, features=SparseVector(10, {0: -0.062, 1: 0.6546, 2: -0.6979, 3: 0.6677, 4: -0.0794, 5: -0.4389, 6: -0.6081, 7: -0.6415, 8: 0.7314, 9: -0.0268})),
# ...

# %%
model=LinearRegression(maxIter=10, regParam=0.3, elasticNetParam=0.8)

# %%
lrmodel=model.fit(data)

# %%
lrmodel.coefficients
lrmodel.intercept
# Out:
# Out[5]: 0.15989368442397356

# %%
trainsum=lrmodel.summary

# %%
trainsum.r2
# Out:
# Out[7]: 0.022861466913958406

# %%
trainsum.totalIterations
# Out:
# Out[8]: 6

# %%
trainsum.residuals.show()
# Out:
# /databricks/spark/python/pyspark/sql/context.py:134: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# +--------------------+
# |           residuals|
# +--------------------+
# |  -9.889232683103197|
# |  0.5533794340053553|
# |  -5.204019455758822|
# | -20.566686715507508|
# |    -9.4497405180564|
# |  -6.909112502719487|
# |  -10.00431602969873|
# |  2.0623978070504845|
# |  3.1117508432954772|
# |  -15.89360822941938|
# |  -5.036284254673026|
# |  6.4832158769943335|
# |  12.429497299109002|
# |  -20.32003219007654|
# |    -2.0049838218725|
# | -17.867901734183793|
# |   7.646455887420495|
# | -2.2653482182417406|
# |-0.10308920436195645|
# |  -1.380034070385301|
# +--------------------+
# only showing top 20 rows

# %%
trainsum.rootMeanSquaredError
# Out:
# Out[10]: 10.189077167598473

# %% [markdown]
# # Decision Tree Regressor

# %%
data=spark.read.format('libsvm').load("/FileStore/tables/sample_linear_regression_data.txt")
data.collect()
# Out:
# Out[11]: [Row(label=-9.490009878824548, features=SparseVector(10, {0: 0.4551, 1: 0.3664, 2: -0.3826, 3: -0.4458, 4: 0.3311, 5: 0.8067, 6: -0.2624, 7: -0.4485, 8: -0.0727, 9: 0.5658})),
#  Row(label=0.2577820163584905, features=SparseVector(10, {0: 0.8387, 1: -0.127, 2: 0.4998, 3: -0.2269, 4: -0.6452, 5: 0.1887, 6: -0.5805, 7: 0.6519, 8: -0.6556, 9: 0.1749})),
#  Row(label=-4.438869807456516, features=SparseVector(10, {0: 0.5026, 1: 0.1421, 2: 0.16, 3: 0.505, 4: -0.9372, 5: -0.2842, 6: 0.6356, 7: -0.1646, 8: 0.9481, 9: 0.4268})),
#  Row(label=-19.782762789614537, features=SparseVector(10, {0: -0.0389, 1: -0.4167, 2: 0.8997, 3: 0.641, 4: 0.2733, 5: -0.2618, 6: -0.2795, 7: -0.1307, 8: -0.0854, 9: -0.0546})),
#  Row(label=-7.966593841555266, features=SparseVector(10, {0: -0.062, 1: 0.6546, 2: -0.6979, 3: 0.6677, 4: -0.0794, 5: -0.4389, 6: -0.6081, 7: -0.6415, 8: 0.7314, 9: -0.0268})),
# ...

# %%
feature=VectorIndexer(inputCol='features',outputCol='indexedfeatures').fit(data)

# %%
(train,test)=data.randomSplit([0.7,0.3])

# %%
dt=DecisionTreeRegressor(featuresCol='indexedfeatures')

# %%
pipe=Pipeline(stages=[feature,dt])

# %%
model=pipe.fit(train)

# %%
predictions=model.transform(test)

# %%
predictions.select("prediction", "label", "features").show(5)
# Out:
# +--------------------+-------------------+--------------------+
# |          prediction|              label|            features|
# +--------------------+-------------------+--------------------+
# |  -8.234803353313717|-26.805483428483072|(10,[0,1,2,3,4,5,...|
# |-0.02024902538219...| -23.51088409032297|(10,[0,1,2,3,4,5,...|
# | -3.3789741382981666|-23.487440120936512|(10,[0,1,2,3,4,5,...|
# |   7.358280303892792|-22.837460416919342|(10,[0,1,2,3,4,5,...|
# |  3.9822572381401606|-19.782762789614537|(10,[0,1,2,3,4,5,...|
# +--------------------+-------------------+--------------------+
# only showing top 5 rows

# %%
# 
evaluator = RegressionEvaluator(
    labelCol="label", predictionCol="prediction", metricName="rmse")
rmse = evaluator.evaluate(predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# Root Mean Squared Error (RMSE) on test data = 11.6001
